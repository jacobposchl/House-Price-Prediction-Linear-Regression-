# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split
X = data.drop(['median_house_value'], axis = 1)
y = data['median_house_value']

# %%
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
train_data = X_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 18074    -122.00     37.28                32.0       2782.0           495.0
# 16847    -122.41     37.61                46.0       2975.0           643.0
# 8394     -118.36     33.96                37.0       2146.0           573.0
# 4303     -118.30     34.09                29.0       3245.0          1190.0
# 15309    -117.38     33.19                35.0        928.0           264.0
# ...          ...       ...                 ...          ...             ...
# 16684    -120.59     35.11                25.0       3642.0           726.0
# 2771     -115.90     33.34                19.0       1210.0           248.0
# 19711    -121.65     39.16                16.0       5022.0          1103.0
# 17856    -121.89     37.45                15.0       2428.0           513.0
# 2630     -124.21     40.75                32.0       1218.0           331.0
#
#        population  households  median_income ocean_proximity  \
# 18074      1092.0       455.0         5.4103       <1H OCEAN
# 16847      1479.0       577.0         3.8214      NEAR OCEAN
# 8394       2009.0       592.0         3.6583       <1H OCEAN
# 4303       3906.0      1102.0         2.1927       <1H OCEAN
# 15309       538.0       248.0         2.4583      NEAR OCEAN
# ...           ...         ...            ...             ...
# 16684      1729.0       673.0         3.1550       <1H OCEAN
# 2771        329.0       155.0         1.7857          INLAND
# 19711      2087.0       956.0         2.3963          INLAND
# 17856      1687.0       519.0         4.7500       <1H OCEAN
# 2630        620.0       268.0         1.6528      NEAR OCEAN
#
#        median_house_value
# 18074            335900.0
# 16847            273600.0
# 8394             177300.0
# 4303             253300.0
# 15309            197900.0
# ...                   ...
# 16684            205400.0
# 2771              62800.0
# 19711            114800.0
# 17856            254400.0
# 2630              58100.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.corr(numeric_only = True)
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924190           -0.102035     0.042089
# latitude            -0.924190  1.000000            0.004711    -0.032123
# housing_median_age  -0.102035  0.004711            1.000000    -0.360891
# total_rooms          0.042089 -0.032123           -0.360891     1.000000
# total_bedrooms       0.065370 -0.061328           -0.323880     0.931749
# population           0.095401 -0.103913           -0.294622     0.853554
# households           0.051510 -0.065690           -0.305698     0.919163
# median_income       -0.012940 -0.083195           -0.113987     0.197929
# median_house_value  -0.045117 -0.145000            0.110114     0.131755
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.065370    0.095401    0.051510      -0.012940
# latitude                 -0.061328   -0.103913   -0.065690      -0.083195
# housing_median_age       -0.323880   -0.294622   -0.305698      -0.113987
# total_rooms               0.931749    0.853554    0.919163       0.197929
# total_bedrooms            1.000000    0.875430    0.979083      -0.006390
# population                0.875430    1.000000    0.905338       0.005857
# households                0.979083    0.905338    1.000000       0.014386
# median_income            -0.006390    0.005857    0.014386       1.000000
# median_house_value        0.047997   -0.026845    0.062564       0.688645
#
#                     median_house_value
# longitude                    -0.045117
# latitude                     -0.145000
# housing_median_age            0.110114
# total_rooms                   0.131755
# total_bedrooms                0.047997
# population                   -0.026845
# households                    0.062564
# median_income                 0.688645
# median_house_value            1.000000

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(numeric_only = True), annot = True, cmap = "YlGnBu")
# Out:
# <Axes: >

# %%
 train_data['total_rooms'] = np.log(train_data['total_rooms'] + 1)
 train_data['total_bedrooms'] = np.log(train_data['total_bedrooms'] + 1)
 train_data['population'] = np.log(train_data['population'] + 1)
 train_data['households'] = np.log(train_data['households'] + 1)

# %%
train_data.hist(figsize = (15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7251
# INLAND        5208
# NEAR OCEAN    2097
# NEAR BAY      1786
# ISLAND           4
# Name: count, dtype: int64

# %%
train_data = train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(["ocean_proximity"], axis=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 18074    -122.00     37.28                32.0     2.189560        6.206576
# 16847    -122.41     37.61                46.0     2.197040        6.467699
# 8394     -118.36     33.96                37.0     2.160079        6.352629
# 4303     -118.30     34.09                29.0     2.206644        7.082549
# 15309    -117.38     33.19                35.0     2.058487        5.579730
# ...          ...       ...                 ...          ...             ...
# 16684    -120.59     35.11                25.0     2.219265        6.588926
# 2771     -115.90     33.34                19.0     2.091766        5.517453
# 19711    -121.65     39.16                16.0     2.253582        7.006695
# 17856    -121.89     37.45                15.0     2.174210        6.242223
# 2630     -124.21     40.75                32.0     2.092578        5.805135
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 18074    6.996681    6.122493         5.4103            335900.0       True
# 16847    7.299797    6.359574         3.8214            273600.0      False
# 8394     7.605890    6.385194         3.6583            177300.0       True
# 4303     8.270525    7.005789         2.1927            253300.0       True
# 15309    6.289716    5.517453         2.4583            197900.0      False
# ...           ...         ...            ...                 ...        ...
# 16684    7.455877    6.513230         3.1550            205400.0       True
# 2771     5.799093    5.049856         1.7857             62800.0      False
# 19711    7.643962    6.863803         2.3963            114800.0      False
# 17856    7.431300    6.253829         4.7500            254400.0       True
# 2630     6.431331    5.594711         1.6528             58100.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 18074   False   False     False       False
# 16847   False   False     False        True
# 8394    False   False     False       False
# 4303    False   False     False       False
# 15309   False   False     False        True
# ...       ...     ...       ...         ...
# 16684   False   False     False       False
# 2771     True   False     False       False
# 19711    True   False     False       False
# 17856   False   False     False       False
# 2630    False   False     False        True
#
# [16346 rows x 14 columns]

# %%
# Convert boolean columns to integers (1 and 0)
boolean_columns = ['<1H OCEAN', 'INLAND', 'ISLAND', 'NEAR BAY', 'NEAR OCEAN']
train_data[boolean_columns] = train_data[boolean_columns].astype(int)

# Display the updated DataFrame
train_data.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 18074    -122.00     37.28                32.0     2.189560        6.206576
# 16847    -122.41     37.61                46.0     2.197040        6.467699
# 8394     -118.36     33.96                37.0     2.160079        6.352629
# 4303     -118.30     34.09                29.0     2.206644        7.082549
# 15309    -117.38     33.19                35.0     2.058487        5.579730
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 18074    6.996681    6.122493         5.4103            335900.0          1
# 16847    7.299797    6.359574         3.8214            273600.0          0
# 8394     7.605890    6.385194         3.6583            177300.0          1
# 4303     8.270525    7.005789         2.1927            253300.0          1
# 15309    6.289716    5.517453         2.4583            197900.0          0
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 18074       0       0         0           0
# 16847       0       0         0           1
# 8394        0       0         0           0
# 4303        0       0         0           0
# 15309       0       0         0           1

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 18074    -122.00     37.28                32.0     2.189560        6.206576
# 16847    -122.41     37.61                46.0     2.197040        6.467699
# 8394     -118.36     33.96                37.0     2.160079        6.352629
# 4303     -118.30     34.09                29.0     2.206644        7.082549
# 15309    -117.38     33.19                35.0     2.058487        5.579730
# ...          ...       ...                 ...          ...             ...
# 16684    -120.59     35.11                25.0     2.219265        6.588926
# 2771     -115.90     33.34                19.0     2.091766        5.517453
# 19711    -121.65     39.16                16.0     2.253582        7.006695
# 17856    -121.89     37.45                15.0     2.174210        6.242223
# 2630     -124.21     40.75                32.0     2.092578        5.805135
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 18074    6.996681    6.122493         5.4103            335900.0          1
# 16847    7.299797    6.359574         3.8214            273600.0          0
# 8394     7.605890    6.385194         3.6583            177300.0          1
# 4303     8.270525    7.005789         2.1927            253300.0          1
# 15309    6.289716    5.517453         2.4583            197900.0          0
# ...           ...         ...            ...                 ...        ...
# 16684    7.455877    6.513230         3.1550            205400.0          1
# 2771     5.799093    5.049856         1.7857             62800.0          0
# 19711    7.643962    6.863803         2.3963            114800.0          0
# 17856    7.431300    6.253829         4.7500            254400.0          1
# 2630     6.431331    5.594711         1.6528             58100.0          0
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 18074       0       0         0           0
# 16847       0       0         0           1
# 8394        0       0         0           0
# 4303        0       0         0           0
# 15309       0       0         0           1
# ...       ...     ...       ...         ...
# 16684       0       0         0           0
# 2771        1       0         0           0
# 19711       1       0         0           0
# 17856       0       0         0           0
# 2630        0       0         0           1
#
# [16346 rows x 14 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(numeric_only = True), annot = True, cmap = "YlGnBu")
# Out:
# <Axes: >

# %%
train_data['bedroom_ratio'] = train_data['total_bedrooms'] / train_data['total_rooms']
train_data["household_rooms"] = train_data["total_rooms"] / train_data["households"]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(numeric_only = True), annot = True, cmap = "YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train, y_train = train_data.drop(['median_house_value'], axis = 1), train_data["median_house_value"]
X_train_s = scaler.fit_transform(X_train)


reg = LinearRegression()
reg.fit(X_train_s, y_train)
# Out:
# LinearRegression()

# %%
# Out:
# LinearRegression()

# %%
test_data = X_test.join(y_test)

test_data['total_rooms'] = np.log(test_data['total_rooms'] + 1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] + 1)
test_data['population'] = np.log(test_data['population'] + 1)
test_data['households'] = np.log(test_data['households'] + 1)

test_data = test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(["ocean_proximity"], axis=1)

test_data['bedroom_ratio'] = test_data['total_bedrooms'] / test_data['total_rooms']
test_data["household_rooms"] = test_data["total_rooms"] / test_data["households"]

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14205    -117.06     32.69                13.0     6.559615        5.010635
# 12065    -117.55     33.85                 4.0     9.012865        7.225481
# 12673    -121.40     38.49                12.0     8.894396        7.157735
# 1700     -122.27     37.97                10.0     9.632990        7.730175
# 14535    -117.14     32.93                12.0     7.296413        5.899897
# ...          ...       ...                 ...          ...             ...
# 9619     -120.43     37.35                15.0     7.386471        5.318120
# 6501     -118.05     34.08                34.0     6.350886        5.043425
# 17982    -121.94     37.30                30.0     7.472501        5.517453
# 13606    -117.27     34.17                16.0     3.433987        1.386294
# 19490    -120.99     37.66                46.0     7.467942        5.852202
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 14205    6.577861    5.049856         4.4375            154900.0      False
# 12065    8.265650    7.173958         4.8686            195300.0      False
# 12673    8.284252    7.130099         3.5968            106300.0      False
# 1700     8.891099    7.757479         6.0666            272400.0      False
# 14535    6.917706    5.921578         4.0521            166700.0       True
# ...           ...         ...            ...                 ...        ...
# 9619     6.513230    5.365976         5.9378            212200.0      False
# 6501     6.624065    5.209486         2.0433            138800.0       True
# 17982    6.703188    5.549076         6.6230            332500.0       True
# 13606    3.912023    2.197225         4.6250            250000.0      False
# 19490    6.626718    5.877736         2.9137            106000.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 14205   False   False     False        True       0.763861         1.298971
# 12065    True   False     False       False       0.801685         1.256331
# 12673    True   False     False       False       0.804747         1.247444
# 1700    False   False      True       False       0.802469         1.241768
# 14535   False   False     False       False       0.808602         1.232174
# ...       ...     ...       ...         ...            ...              ...
# 9619     True   False     False       False       0.719981         1.376538
# 6501    False   False     False       False       0.794129         1.219100
# 17982   False   False     False       False       0.738368         1.346621
# 13606    True   False     False       False       0.403698         1.562875
# 19490    True   False     False       False       0.783643         1.270547
#
# [4087 rows x 16 columns]

# %%
# Convert boolean columns to integers (1 and 0)
boolean_columns = ['<1H OCEAN', 'INLAND', 'ISLAND', 'NEAR BAY', 'NEAR OCEAN']
test_data[boolean_columns] = test_data[boolean_columns].astype(int)

# Display the updated DataFrame
test_data.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14205    -117.06     32.69                13.0     6.559615        5.010635
# 12065    -117.55     33.85                 4.0     9.012865        7.225481
# 12673    -121.40     38.49                12.0     8.894396        7.157735
# 1700     -122.27     37.97                10.0     9.632990        7.730175
# 14535    -117.14     32.93                12.0     7.296413        5.899897
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 14205    6.577861    5.049856         4.4375            154900.0          0
# 12065    8.265650    7.173958         4.8686            195300.0          0
# 12673    8.284252    7.130099         3.5968            106300.0          0
# 1700     8.891099    7.757479         6.0666            272400.0          0
# 14535    6.917706    5.921578         4.0521            166700.0          1
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 14205       0       0         0           1       0.763861         1.298971
# 12065       1       0         0           0       0.801685         1.256331
# 12673       1       0         0           0       0.804747         1.247444
# 1700        0       0         1           0       0.802469         1.241768
# 14535       0       0         0           0       0.808602         1.232174

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14205    -117.06     32.69                13.0     6.559615        5.010635
# 12065    -117.55     33.85                 4.0     9.012865        7.225481
# 12673    -121.40     38.49                12.0     8.894396        7.157735
# 1700     -122.27     37.97                10.0     9.632990        7.730175
# 14535    -117.14     32.93                12.0     7.296413        5.899897
# ...          ...       ...                 ...          ...             ...
# 9619     -120.43     37.35                15.0     7.386471        5.318120
# 6501     -118.05     34.08                34.0     6.350886        5.043425
# 17982    -121.94     37.30                30.0     7.472501        5.517453
# 13606    -117.27     34.17                16.0     3.433987        1.386294
# 19490    -120.99     37.66                46.0     7.467942        5.852202
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 14205    6.577861    5.049856         4.4375            154900.0          0
# 12065    8.265650    7.173958         4.8686            195300.0          0
# 12673    8.284252    7.130099         3.5968            106300.0          0
# 1700     8.891099    7.757479         6.0666            272400.0          0
# 14535    6.917706    5.921578         4.0521            166700.0          1
# ...           ...         ...            ...                 ...        ...
# 9619     6.513230    5.365976         5.9378            212200.0          0
# 6501     6.624065    5.209486         2.0433            138800.0          1
# 17982    6.703188    5.549076         6.6230            332500.0          1
# 13606    3.912023    2.197225         4.6250            250000.0          0
# 19490    6.626718    5.877736         2.9137            106000.0          0
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 14205       0       0         0           1       0.763861         1.298971
# 12065       1       0         0           0       0.801685         1.256331
# 12673       1       0         0           0       0.804747         1.247444
# 1700        0       0         1           0       0.802469         1.241768
# 14535       0       0         0           0       0.808602         1.232174
# ...       ...     ...       ...         ...            ...              ...
# 9619        1       0         0           0       0.719981         1.376538
# 6501        0       0         0           0       0.794129         1.219100
# 17982       0       0         0           0       0.738368         1.346621
# 13606       1       0         0           0       0.403698         1.562875
# 19490       1       0         0           0       0.783643         1.270547
#
# [4087 rows x 16 columns]

# %%
X_test, y_test = test_data.drop(['median_house_value'], axis = 1), test_data["median_house_value"]

X_test_s = scaler.transform(X_test)

# %%
reg.score(X_test_s, y_test)
# Out:
# -258.7769262826931

# %%
from sklearn.ensemble import RandomForestRegressor
forest = RandomForestRegressor()

forest.fit(X_train_s, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_test_s, y_test)
# Out:
# 0.48821969670093945

# %%
from sklearn.model_selection import GridSearchCV

forest = RandomForestRegressor()

param_grid = {
    "n_estimators": [100, 200, 300],
    "min_samples_split": [2,4],
    "max_depth": [None, 4, 8]

}

grid_search = GridSearchCV(forest, param_grid, cv=5, scoring = "neg_mean_squared_error", return_train_score=True)

grid_search.fit(X_train_s, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [None, 4, 8], 'min_samples_split': [2, 4],
#                          'n_estimators': [100, 200, 300]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(min_samples_split=4, n_estimators=300)

# %%
grid_search.best_estimator_.score(X_test_s, y_test)
# Out:
# 0.4990646791684762
